# %% [markdown]
# # Spotting the Problem
#
# It is good to know how well the trains run according to the schedule and the on-time-performance impact on the customers of BART. What is even better is figuring out what are the potential problems where delays are introduced.
#
# Rather than look at entire journey, we look at the individual segments. Delays are introduced in runs between stations. These stack up and eventually add upto significant impact on the total journey times for customers. So in this notebook, we will walk through how we can identify potential bottlenecks.
#
# We do this by comparing the scheduled travel times with the actual travel times between pairs of stations. The travel times here may identify segments that have chronic issues/delays and help direct the next step analysis.

# %%
import pandas as pd
# Configure some display options for panda frames to ensure we see all columns and rows when needed.
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.precision', 6)
pd.set_option('display.max_colwidth', -1)

import datetime as dt

# Ensure we embedd the graphs we generate within the Notebook
# %matplotlib inline

import numpy as np
from scipy import stats

import seaborn as sns
sns.set(color_codes=True)
sns.set_context("notebook", font_scale=1.1)
sns.set_style("ticks")

import pickle

import pprint

# %%
class TravelStatistics(object):
    def __init__(self, start, end, list_travel_times):
        """Given a TravelRecord with multiple trips, generates statistics including:
         * stats.describe.
         * median (i.e. p50
         * p90
         * p99
         * p99.9
         """
        self._start = start
        self._end = end
        np_array = np.sort(np.fromiter(list_travel_times, np.float))
        
        percentiles = np.percentile(np_array, [50, 75, 90, 95, 99])
        self._p50 = percentiles[0]
        self._p75 = percentiles[1]
        self._p90 = percentiles[2]
        self._p95 = percentiles[3]
        self._p99 = percentiles[4]
        
        stats_obj = stats.describe(np_array)
        self._nobs = stats_obj.nobs
        self._min = stats_obj.minmax[0]
        self._max = stats_obj.minmax[1]
        self._mean = stats_obj.mean
        self._variance = stats_obj.variance
        self._skewness = stats_obj.skewness
        self._kurtosis = stats_obj.kurtosis
        self._mode = stats.mode(np_array)
        #DescribeResult(nobs=238, minmax=(150.0, 4908.0), mean=649.90756302521004, 
        # variance=391391.05471049179, skewness=2.975446304980173, kurtosis=11.555424995051435)
        
    def __str__(self):
        ret = "start={}, end={}".format(self._start, self._end)
        ret += ", nobs={}, min={}, max={}, mode={}".format(self._nobs, self._min, self._max, self._mode)
        ret += ", p50={}, p75={}, p90={}, p95={}, p99={}".format(self._p50, self._p75, self._p90, self._p95, self._p99)
        ret += ", mean={}, variance={}".format(self._mean, self._variance)
        ret += ", skewness={}, kurtosis={}".format(self._skewness, self._kurtosis)        
        return ret

    def __repr__(self):
        return self.__str__()

# %% [markdown]
# ## Datasets
#
# First we will load the the datasets we produced in other notebooks.

# %%
map_actual_travel_times = {}
with open('actual_travel_time_stats.pickle', 'rb') as handle:
    map_actual_travel_times = pickle.loads(handle.read())

# %%
pprint.pprint(map_actual_travel_times['M80']['M90'])
# Out:
# [start=M80, end=M90, nobs=1647, min=7.0, max=16207.0, mode=ModeResult(mode=array([ 507.]), count=array([10])), p50=543.0, p75=767.0, p90=1380.4, p95=2138.5, p99=4049.32, mean=744.21797207, variance=879536.92269, skewness=6.86607674932, kurtosis=76.0343081172]

# %%
map_scheduled_travel_times = {}
with open('schedule_travel_time_stats.pickle', 'rb') as handle:
    map_scheduled_travel_times = pickle.loads(handle.read())

# %%
pprint.pprint(map_scheduled_travel_times['M80']['M90'])
# Out:
# [start=M80, end=M90, nobs=543, min=226.0, max=256.0, mode=ModeResult(mode=array([ 256.]), count=array([299])), p50=256.0, p75=256.0, p90=256.0, p95=256.0, p99=256.0, mean=242.519337017, variance=223.102485168, skewness=-0.203625508646, kurtosis=-1.95853665223]

# %%
time_table = pd.read_csv('tt_of_interest_no_index.csv')

# %%
time_table.head()
# Out:
#   SCH_DAY_TYPE_CODE  ROUTE_B_NUMBER  TRAIN_NUMBER  RUN_U_NUMBER  \
# 0  SA                1               361           5
# 1  SA                1               361           5
# 2  SA                1               361           5
# 3  SA                1               361           5
# 4  SA                1               361           5
#
#    STATION_O_NUMBER STATION_CH3_ABBR          STATION_NAME  \
# 0  41                C80              WEST PITTSBURG
# 1  40                C70              NORTH CONCORD
# 2  19                C60              CONCORD
# 3  18                C50              PLEASANT HILL
# 4  17                C40              WALNUT CREEK
#
#        DOOR_CLOSE_TIME  DOOR_CLOSE_TSEC  DOOR_OPEN_TSEC  LINE_NUMBER  \
# 0  2017-08-15 06:58:23  25103            24983.0         3
# 1  2017-08-15 07:04:30  25470            25455.0         3
# 2  2017-08-15 07:08:04  25684            25669.0         3
# 3  2017-08-15 07:13:28  26008            25993.0         3
# 4  2017-08-15 07:16:05  26165            26150.0         3
#
#   ROUTE_ABBR MAP_COLOR_NAME  FROM_STATION_O_NUM  TO_STATION_O_NUM  \
# 0  CD         YELLOW         41                  38
# 1  CD         YELLOW         41                  38
# 2  CD         YELLOW         41                  38
# 3  CD         YELLOW         41                  38
# 4  CD         YELLOW         41                  38
#
#   FROM_STATION_CH3_ABBR TO_STATION_CH3_ABBR          FROM_STATION  \
# 0  C80                   Y10                 WEST PITTSBURG
# 1  C80                   Y10                 WEST PITTSBURG
# 2  C80                   Y10                 WEST PITTSBURG
# 3  C80                   Y10                 WEST PITTSBURG
# 4  C80                   Y10                 WEST PITTSBURG
#
#              TO_STATION
# 0  S.F. AIRPORT
# 1  S.F. AIRPORT
# 2  S.F. AIRPORT
# 3  S.F. AIRPORT
# 4  S.F. AIRPORT

# %% [markdown]
# Lets build up a look up table to quickly identify the STATION_NAME and MAP_COLOR_NAME

# %%
station_name_color = time_table[['STATION_CH3_ABBR','STATION_NAME', 'MAP_COLOR_NAME']].sort_values('STATION_CH3_ABBR')
station_name_color = station_name_color.drop_duplicates()
station_name_color.set_index('STATION_CH3_ABBR', inplace=True)
station_name_color.shape
# Out:
# (107, 2)

# %%
type(station_name_color.loc['M10'].STATION_NAME[0])
# Out:
# str

# %%
station_name_color
# Out:
#                           STATION_NAME MAP_COLOR_NAME
# STATION_CH3_ABBR
# C80               WEST PITTSBURG        YELLOW
# C70               NORTH CONCORD         YELLOW
# C60               CONCORD               YELLOW
# C50               PLEASANT HILL         YELLOW
# C40               WALNUT CREEK          YELLOW
# C30               LAFAYETTE             YELLOW
# C20               ORINDA                YELLOW
# C10               ROCKRIDGE             YELLOW
# K30               MACARTHUR             YELLOW
# K20               19TH STREET OAKLAND   YELLOW
# K10               12TH STREET OAKLAND   YELLOW
# M10               OAKLAND WEST          YELLOW
# M16               EMBARCADERO           YELLOW
# M20               MONTGOMERY STREET     YELLOW
# M30               POWELL STREET         YELLOW
# M40               CIVIC CENTER          YELLOW
# M50               16TH STREET MISSION   YELLOW
# M60               24TH STREET MISSION   YELLOW
# M70               GLEN PARK             YELLOW
# M80               BALBOA PARK           YELLOW
# M90               DALY CITY             YELLOW
# W10               COLMA                 YELLOW
# W20               SOUTH SAN FRANCISCO   YELLOW
# W30               SAN BRUNO             YELLOW
# Y10               S.F. AIRPORT          YELLOW
# S20               WARM SPRINGS          ORANGE
# A90               FREMONT               ORANGE
# A80               UNION CITY            ORANGE
# A70               SOUTH HAYWARD         ORANGE
# A60               HAYWARD               ORANGE
# A50               BAY FAIR              ORANGE
# A40               SAN LEANDRO           ORANGE
# A30               COLISEUM              ORANGE
# A20               FRUITVALE             ORANGE
# A10               LAKE MERRITT          ORANGE
# K10               12TH STREET OAKLAND   ORANGE
# K20               19TH STREET OAKLAND   ORANGE
# K30               MACARTHUR             ORANGE
# R10               ASHBY PLACE           ORANGE
# R20               BERKELEY              ORANGE
# R30               NORTH BERKELEY        ORANGE
# R40               EL CERRITO PLAZA      ORANGE
# R50               EL CERRITO DEL NORTE  ORANGE
# R60               RICHMOND              ORANGE
# A90               FREMONT               GREEN
# A80               UNION CITY            GREEN
# A70               SOUTH HAYWARD         GREEN
# A60               HAYWARD               GREEN
# A50               BAY FAIR              GREEN
# A40               SAN LEANDRO           GREEN
# A30               COLISEUM              GREEN
# A20               FRUITVALE             GREEN
# A10               LAKE MERRITT          GREEN
# M10               OAKLAND WEST          GREEN
# M16               EMBARCADERO           GREEN
# M20               MONTGOMERY STREET     GREEN
# M30               POWELL STREET         GREEN
# M40               CIVIC CENTER          GREEN
# M50               16TH STREET MISSION   GREEN
# M60               24TH STREET MISSION   GREEN
# M70               GLEN PARK             GREEN
# M80               BALBOA PARK           GREEN
# M90               DALY CITY             GREEN
# R60               RICHMOND              RED
# R50               EL CERRITO DEL NORTE  RED
# R40               EL CERRITO PLAZA      RED
# R30               NORTH BERKELEY        RED
# R20               BERKELEY              RED
# R10               ASHBY PLACE           RED
# K30               MACARTHUR             RED
# K20               19TH STREET OAKLAND   RED
# K10               12TH STREET OAKLAND   RED
# M10               OAKLAND WEST          RED
# M16               EMBARCADERO           RED
# M20               MONTGOMERY STREET     RED
# M30               POWELL STREET         RED
# M40               CIVIC CENTER          RED
# M50               16TH STREET MISSION   RED
# M60               24TH STREET MISSION   RED
# M70               GLEN PARK             RED
# M80               BALBOA PARK           RED
# M90               DALY CITY             RED
# L30               EAST DUBLIN / PLEAS   BLUE
# L20               WEST DUBLIN / PLEAS   BLUE
# L10               CASTRO VALLEY         BLUE
# A50               BAY FAIR              BLUE
# A40               SAN LEANDRO           BLUE
# A30               COLISEUM              BLUE
# A20               FRUITVALE             BLUE
# A10               LAKE MERRITT          BLUE
# M10               OAKLAND WEST          BLUE
# M16               EMBARCADERO           BLUE
# M20               MONTGOMERY STREET     BLUE
# M30               POWELL STREET         BLUE
# M40               CIVIC CENTER          BLUE
# M50               16TH STREET MISSION   BLUE
# M60               24TH STREET MISSION   BLUE
# M70               GLEN PARK             BLUE
# M80               BALBOA PARK           BLUE
# M90               DALY CITY             BLUE
# W40               MILBRAE               VIOLET
# Y10               S.F. AIRPORT          VIOLET
# S20               WARM SPRINGS          GREEN
# W10               COLMA                 RED
# W20               SOUTH SAN FRANCISCO   RED
# W30               SAN BRUNO             RED
# W40               MILBRAE               RED

# %% [markdown]
# ## Comparison

# %%
match = 0
no_match = 0
for start, nested in map_actual_travel_times.iteritems():
    for end, actual_travel_stats in nested.iteritems():
        
        if start in map_scheduled_travel_times:
            if end in map_scheduled_travel_times[start]:
                
                start_name = station_name_color.loc[start].STATION_NAME
                if type(start_name) is not str:
                    start_name = start_name[0]
                end_name = station_name_color.loc[end].STATION_NAME
                if type(end_name) is not str:
                    end_name = end_name[0]
                
                schedule_travel_stats = map_scheduled_travel_times[start][end][0]
                expected_duration = schedule_travel_stats._mode.mode[0]
                actual_duration_median = actual_travel_stats[0]._p50
                print "({}){} -> ({}){}: Expected={} vs {}=Actual".format(start, start_name,end, end_name, expected_duration,actual_duration_median)
                #print "Match: {} -> {}: {}\n".format(start, end, travel_stats)
                #print "   vs: {}\n".format(schedule_travel_stats)
                match += 1
            else:
                no_match += 1
        else:
            no_match += 1
            
print "There were {} matches and {} no matches".format(match, no_match)
# Out:
# (M70)GLEN PARK            -> (M60)24TH STREET MISSION : Expected=164.0 vs 398.0=Actual
# (M70)GLEN PARK            -> (M80)BALBOA PARK         : Expected=137.0 vs 315.5=Actual
# (M50)16TH STREET MISSION  -> (M60)24TH STREET MISSION : Expected=121.0 vs 237.0=Actual
# (M50)16TH STREET MISSION  -> (M40)CIVIC CENTER        : Expected=142.0 vs 296.0=Actual
# (C50)PLEASANT HILL        -> (C40)WALNUT CREEK        : Expected=157.0 vs 374.5=Actual
# (C50)PLEASANT HILL        -> (C60)CONCORD             : Expected=299.0 vs 937.5=Actual
# (L10)CASTRO VALLEY        -> (A50)BAY FAIR            : Expected=285.0 vs 808.0=Actual
# (A80)UNION CITY           -> (A90)FREMONT             : Expected=270.0 vs 730.5=Actual
# (A80)UNION CITY           -> (A70)SOUTH HAYWARD       : Expected=311.0 vs 811.0=Actual
# (M30)POWELL STREET        -> (M40)CIVIC CENTER        : Expected=90.0 vs 153.0=Actual
# (M30)POWELL STREET        -> (M20)MONTGOMERY STREET   : Expected=101.0 vs 153.0=Actual
# (A50)BAY FAIR             -> (A60)HAYWARD             : Expected=232.0 vs 713.0=Actual
# (A50)BAY FAIR             -> (A40)SAN LEANDRO         : Expected=221.0 vs 574.0=Actual
# (K10)12TH STREET OAKLAND  -> (M10)OAKLAND WEST        : Expected=268.0 vs 772.0=Actual
# (K10)12TH STREET OAKLAND  -> (K20)19TH STREET OAKLAND : Expected=103.0 vs 84.0=Actual
# (W20)SOUTH SAN FRANCISCO  -> (W30)SAN BRUNO           : Expected=191.0 vs 477.0=Actual
# (W20)SOUTH SAN FRANCISCO  -> (W10)COLMA               : Expected=196.0 vs 468.5=Actual
# (C10)ROCKRIDGE            -> (C20)ORINDA              : Expected=312.0 vs 936.0=Actual
# (C10)ROCKRIDGE            -> (K30)MACARTHUR           : Expected=284.0 vs 423.0=Actual
# (A90)FREMONT              -> (A80)UNION CITY          : Expected=255.0 vs 733.0=Actual
# (A90)FREMONT              -> (S20)WARM SPRINGS        : Expected=420.0 vs 1104.0=Actual
# (K30)MACARTHUR            -> (K20)19TH STREET OAKLAND : Expected=207.0 vs 493.0=Actual
# (K30)MACARTHUR            -> (C10)ROCKRIDGE           : Expected=148.0 vs 454.0=Actual
# (K30)MACARTHUR            -> (R10)ASHBY PLACE         : Expected=192.0 vs 489.0=Actual
# (A30)COLISEUM             -> (A40)SAN LEANDRO         : Expected=239.0 vs 638.0=Actual
# (A10)LAKE MERRITT         -> (A20)FRUITVALE           : Expected=230.0 vs 665.0=Actual
# (A10)LAKE MERRITT         -> (M10)OAKLAND WEST        : Expected=315.0 vs 921.0=Actual
# (A10)LAKE MERRITT         -> (K10)12TH STREET OAKLAND : Expected=189.0 vs 355.0=Actual
# (R10)ASHBY PLACE          -> (K30)MACARTHUR           : Expected=417.0 vs 492.5=Actual
# (R10)ASHBY PLACE          -> (R20)BERKELEY            : Expected=140.0 vs 290.0=Actual
# (M80)BALBOA PARK          -> (M90)DALY CITY           : Expected=256.0 vs 543.0=Actual
# (M80)BALBOA PARK          -> (M70)GLEN PARK           : Expected=138.0 vs 326.0=Actual
# (A70)SOUTH HAYWARD        -> (A80)UNION CITY          : Expected=288.0 vs 909.0=Actual
# (A70)SOUTH HAYWARD        -> (A60)HAYWARD             : Expected=243.0 vs 675.0=Actual
# (L20)WEST DUBLIN / PLEAS  -> (L10)CASTRO VALLEY       : Expected=584.0 vs 1584.0=Actual
# (L20)WEST DUBLIN / PLEAS  -> (L30)EAST DUBLIN / PLEAS : Expected=215.0 vs 413.5=Actual
# (R60)RICHMOND             -> (R50)EL CERRITO DEL NORTE: Expected=225.0 vs 679.0=Actual
# (R50)EL CERRITO DEL NORTE -> (R60)RICHMOND            : Expected=281.0 vs 584.0=Actual
# (R50)EL CERRITO DEL NORTE -> (R40)EL CERRITO PLAZA    : Expected=192.0 vs 538.5=Actual
# (R30)NORTH BERKELEY       -> (R40)EL CERRITO PLAZA    : Expected=198.0 vs 468.5=Actual
# (R30)NORTH BERKELEY       -> (R20)BERKELEY            : Expected=144.0 vs 324.0=Actual
# (M40)CIVIC CENTER         -> (M50)16TH STREET MISSION : Expected=134.0 vs 306.0=Actual
# (M40)CIVIC CENTER         -> (M30)POWELL STREET       : Expected=98.0 vs 157.0=Actual
# (M60)24TH STREET MISSION  -> (M70)GLEN PARK           : Expected=165.0 vs 480.0=Actual
# (M60)24TH STREET MISSION  -> (M50)16TH STREET MISSION : Expected=117.0 vs 343.0=Actual
# (A20)FRUITVALE            -> (A30)COLISEUM            : Expected=189.0 vs 479.0=Actual
# (A20)FRUITVALE            -> (A10)LAKE MERRITT        : Expected=266.0 vs 777.0=Actual
# (C20)ORINDA               -> (C10)ROCKRIDGE           : Expected=333.0 vs 919.5=Actual
# (C20)ORINDA               -> (C30)LAFAYETTE           : Expected=280.0 vs 763.0=Actual
# (C40)WALNUT CREEK         -> (C30)LAFAYETTE           : Expected=276.0 vs 711.0=Actual
# (C40)WALNUT CREEK         -> (C50)PLEASANT HILL       : Expected=164.0 vs 476.0=Actual
# (K20)19TH STREET OAKLAND  -> (K10)12TH STREET OAKLAND : Expected=96.0 vs 113.0=Actual
# (K20)19TH STREET OAKLAND  -> (K30)MACARTHUR           : Expected=214.0 vs 518.0=Actual
# (M16)EMBARCADERO          -> (M10)OAKLAND WEST        : Expected=414.0 vs 1227.0=Actual
# (M16)EMBARCADERO          -> (M20)MONTGOMERY STREET   : Expected=88.0 vs 284.5=Actual
# (M20)MONTGOMERY STREET    -> (M16)EMBARCADERO         : Expected=104.0 vs 170.0=Actual
# (M20)MONTGOMERY STREET    -> (M30)POWELL STREET       : Expected=93.0 vs 232.0=Actual
# (C60)CONCORD              -> (C70)NORTH CONCORD       : Expected=189.0 vs 539.0=Actual
# (W30)SAN BRUNO            -> (Y10)S.F. AIRPORT        : Expected=280.0 vs 575.5=Actual
# (W30)SAN BRUNO            -> (W20)SOUTH SAN FRANCISCO : Expected=198.0 vs 631.0=Actual
# (S20)WARM SPRINGS         -> (A90)FREMONT             : Expected=375.0 vs 1732.5=Actual
# (A40)SAN LEANDRO          -> (A50)BAY FAIR            : Expected=217.0 vs 586.0=Actual
# (Y10)S.F. AIRPORT         -> (W30)SAN BRUNO           : Expected=286.0 vs 800.5=Actual
# (C80)WEST PITTSBURG       -> (C70)NORTH CONCORD       : Expected=367.0 vs 1907.0=Actual
# (M90)DALY CITY            -> (M80)BALBOA PARK         : Expected=211.0 vs 679.0=Actual
# (M90)DALY CITY            -> (W10)COLMA               : Expected=225.0 vs 813.0=Actual
# (A60)HAYWARD              -> (A50)BAY FAIR            : Expected=255.0 vs 747.0=Actual
# (A60)HAYWARD              -> (A70)SOUTH HAYWARD       : Expected=230.0 vs 742.5=Actual
# (W10)COLMA                -> (M90)DALY CITY           : Expected=220.0 vs 555.5=Actual
# (W10)COLMA                -> (W20)SOUTH SAN FRANCISCO : Expected=183.0 vs 572.0=Actual
# (M10)OAKLAND WEST         -> (K10)12TH STREET OAKLAND : Expected=223.0 vs 614.0=Actual
# (M10)OAKLAND WEST         -> (A10)LAKE MERRITT        : Expected=315.0 vs 1024.0=Actual
# (M10)OAKLAND WEST         -> (M16)EMBARCADERO         : Expected=432.0 vs 1172.0=Actual
# (R40)EL CERRITO PLAZA     -> (R50)EL CERRITO DEL NORTE: Expected=175.0 vs 414.5=Actual
# (R40)EL CERRITO PLAZA     -> (R30)NORTH BERKELEY      : Expected=200.0 vs 522.0=Actual
# (L30)EAST DUBLIN / PLEAS  -> (L20)WEST DUBLIN / PLEAS : Expected=180.0 vs 405.0=Actual
# (C30)LAFAYETTE            -> (C20)ORINDA              : Expected=291.0 vs 746.0=Actual
# (C30)LAFAYETTE            -> (C40)WALNUT CREEK        : Expected=261.0 vs 720.5=Actual
# (R20)BERKELEY             -> (R30)NORTH BERKELEY      : Expected=143.0 vs 250.0=Actual
# (R20)BERKELEY             -> (R10)ASHBY PLACE         : Expected=143.0 vs 273.0=Actual
# There were 80 matches and 74 no matches
