# %%
import pandas as pd

# %%
test = pd.read_csv('bart_locations.csv')

# %%
test.head()
# Out:
#   station_q_number        Country station_ch5_abbr station_ch8_abbr  \
# 0               27  United States            MONTG         MONTGMRY
# 1               32  United States            GLNPK         GLEN PRK
# 2                4  United States            NBERK         NO BRKLY
# 3               38  United States            NCONC         N CONCRD
# 4               40  United States            WDUBL         W DUBLIN
#
#    station_p_number  station_o_number           city  station_r_number  \
# 0              27.0              27.0  San Francisco              41.0
# 1              32.0              32.0  San Francisco              46.0
# 2               4.0              22.0       Berkeley              13.0
# 3              35.0              40.0        Concord              31.0
# 4              38.0              45.0         Dublin               9.0
#
#          county bart_station_geo_country_geo_city  \
# 0  sanfrancisco                     San Francisco
# ...
